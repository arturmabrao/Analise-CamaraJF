# %%
import pandas as pd
pd.options.mode.chained_assignment = None  # default='warn'

import re
import requests
from bs4 import BeautifulSoup

import time
from pathlib import Path

# GetDate
from datetime import datetime #,  date

# %%
id_proj = 119950
#id_proj = listagem['Id_Projeto_Camara'][i]

#try
with requests.Session() as session:
            
    query = {"num": id_proj}
    resposta = session.get('https://www.camarajf.mg.gov.br/sal/proposicao.php?', params=query)
# req = (response.content.upper())

    resp_format = BeautifulSoup(resposta.content, "html.parser")
    
    fnd_proposicoes = resp_format.find('font', 
                                        {'face':'courier new,arial,verdana'}
                                      ).find('table',
                                             {'width':'98%',
                                              'border':'0'})#.find({'width':'98%' 'border':'0}).tr.td.find_all('a', 
                                            #                                                   {'target':'blank'})
    #fnd_proposicoes = resp_format.find('table', 
    #                                    {'width':'98%',
    #                                     'border':'0'})
                                    
#requisicao = ''.join(map(chr, response.content.upper()))
#requisicao = requisicao.replace('\n', '')
#requisicao = requisicao.replace('\r', '')
#requisicao = requisicao.replace('\t', '')
#requisicao = requisicao.replace('ALIGN="LEFT">&NBSP;</TD>', '/>')
#requisicao = requisicao.replace('&NBSP;', '')


#corpo = re.search('PROPOSICAON(.+?)TABLE', requisicao)
#corpos = re.search('INICIO DA AREA DE OPERACOES: -->(.+?)<!-- FIM DA AREA DE OPERACOES:', requisicao)

#id_proposicao = re.search('PROPOSICAON=(.+?)TARGET', requisicao)

#elementos = re.findall('TD(.+?)</TD', corpos.group(1))
#ocorrencias = re.findall('ENCONTRADA (.+?) OCORR', corpos.group(1))
#ocorrencias = int(ocorrencias[0])
#cabecalhos = re.findall('ALIGN="LEFT">(.+?)</', corpos.group(1))
#dados = re.findall('TARGET=BLANK>(.+?)</A', corpos.group(1))

#id_proposicao = re.findall('<A HREF="PROPOSICAON.PHP?NUM=',cabecalhos[6].group(1))

#cabecalhos[6] = cabecalhos[6].replace('<DIV ALIGN="LEFT">', '')
#cabecalhos = cabecalhos[0:7]
#dados[4] = dados[4].replace('<SPAN STYLE="TEXT-ALIGN: JUSTIFY; DISPLAY:BLOCK;">', '')
#dados[4] = dados[4].replace('</SPAN>', '')
#dados[4] = dados[4].replace('</SPAN>', '')

# print(ocorrencias)


# print((corpos.group(1)))
# print((elementos[1]))
# print((elementos))
#print((cabecalhos))

print((fnd_proposicoes))

#print((requisicao))

#print((ocorrencias))



#text = 'gfgfdAAA1234ZZZuijjk'
#found = re.search('AAA(.+?)ZZZ', text).group(1)
# Out:
# <table border="0" width="98%">
# <tr>
# <td align="right" valign="top" width="10%">
# <font size="3"><b>Proposição:</b></font>
# </td>
# <td>
# <font size="3"><b>REQ - Requerimento<br/>
# <font face="courier new,arial,verdana">Número</font>: 12995/2022</b></font>
# </td>
# </tr>
# <tr>
# <td align="right" valign="top" width="10%">
# <b><font size="2">Autor(es):</font></b>
# </td>
# <td>
# <font size="2">Juraci Scheffer</font>
# </td>
# </tr>
# <tr>
# <td align="right" valign="top" width="10%">
# <b><font size="2">Ementa:</font></b>
# </td>
# <td>
# <p align="justify"><font size="2">Desentupimento e conserto de vazamento da rede de esgoto no meio da Rua Papa João Paulo II, Bairro Caiçaras</font></p>
# </td>
# </tr>
# <tr>
# <td align="right" valign="top" width="10%">
# <b><font size="2">Situação:</font></b>
# </td>
# <td>
# <p align="justify"><font size="2">
#
# 			  Aprovado - Fim tramitação: Sim						</font></p>
# </td>
# </tr>
#
# <tr>
# <td colspan="2">
#
#         </td>
# </tr>
# <tr>
# <td align="right" valign="top" width="10%">
# <b><font size="2">Tramitação:</font></b>
# </td>
# <td>
# <hr/>
# </td>
# </tr><tr>
# <td width="10%">
# </td>
# <td bgcolor="#FFFFFF">
# <font size="2">Período: 29/11/2022 a 29/11/2022 <br/> Aprovado</font>
# </td>
# </tr>
# <tr>
# <td width="10%">
# </td>
# <td>
# <hr/>
# </td>
# </tr>
# <tr>
# <td align="right" valign="top" width="10%">
# <b><font size="2">Textos:</font></b>
# </td>
# <td>
# <font size="2"><font size="2"><a href="mostrapfs.php?n=119950" onclick="window.open(this.href, 'childddd', 'scrollbars,width=850,height=600'); return false">Requerimento <i aria-hidden="true" class="fa fa-file-pdf-o"></i></a></font></font>
# </td>
# </tr><td width="10%">
#
#                            </td>
# <td>
# <hr/>
# </td>
#
# </table>
