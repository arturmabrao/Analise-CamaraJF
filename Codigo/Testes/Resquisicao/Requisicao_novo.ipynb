# %%
import re
import requests
from bs4 import BeautifulSoup

# %%
#query = {"numero": 204700, "ano": 2012, "tipo": 'REQ'}
query = {"numero": 22, "ano": 2017, "codtipo": 'PEDIF'}
response = requests.get('https://www.camarajf.mg.gov.br/sal/listapropos.php?', params=query)
# req = (response.content.upper())

requisicao = ''.join(map(chr, response.content.upper()))
requisicao = requisicao.replace('\n', '')
requisicao = requisicao.replace('\r', '')
requisicao = requisicao.replace('\t', '')
requisicao = requisicao.replace('ALIGN="LEFT">&NBSP;</TD>', '/>')
requisicao = requisicao.replace('&NBSP;', '')


corpo = re.search('PROPOSICAON(.+?)TABLE', requisicao)
corpos = re.search('INICIO DA AREA DE OPERACOES: -->(.+?)<!-- FIM DA AREA DE OPERACOES:', requisicao)

#id_proposicao = re.search('PROPOSICAON=(.+?)TARGET', requisicao)

elementos = re.findall('TD(.+?)</TD', corpos.group(1))
ocorrencias = re.findall('ENCONTRADA (.+?) OCORR', corpos.group(1))
#ocorrencias = int(ocorrencias[0])
cabecalhos = re.findall('ALIGN="LEFT">(.+?)</', corpos.group(1))
dados = re.findall('TARGET=BLANK>(.+?)</A', corpos.group(1))

#id_proposicao = re.findall('<A HREF="PROPOSICAON.PHP?NUM=',cabecalhos[6].group(1))

cabecalhos[6] = cabecalhos[6].replace('<DIV ALIGN="LEFT">', '')
cabecalhos = cabecalhos[0:7]
dados[4] = dados[4].replace('<SPAN STYLE="TEXT-ALIGN: JUSTIFY; DISPLAY:BLOCK;">', '')
dados[4] = dados[4].replace('</SPAN>', '')
dados[4] = dados[4].replace('</SPAN>', '')

# print(ocorrencias)


# print((corpos.group(1)))
# print((elementos[1]))
# print((elementos))
#print((cabecalhos))

print((dados))

#print((requisicao))

#print((ocorrencias))



#text = 'gfgfdAAA1234ZZZuijjk'
#found = re.search('AAA(.+?)ZZZ', text).group(1)
# Out:
# ['022', '2017', 'PEDIDO DE INFORMAçãO FISCALIZAJF', 'MESA DIRETORA - BIêNIO 2017/2018', 'SOLICITA INFORMAçõES SOBRE A ESCOLA MUNICIPAL JARDIM DE ALá.', 'ARQUIVADA', '022', '2017', 'PEDIDO DE INFORMAçãO', 'SARGENTO MELLO CASAL', '<SPAN STYLE="TEXT-ALIGN: JUSTIFY; DISPLAY:BLOCK;">SOLICITA INFORMAçõES SOBRE OS PROFISSIONAIS NãO DOCENTES DAS INSTITUIçõES DE EDUCAçãO INFANTIL, PúBLICAS E PRIVADAS.</SPAN>', 'ARQUIVADA']

# %%
with requests.Session() as session:
    
    id_projeto = ''
    failed = False
    
    # Variaveis de requisicao
    num_proj = 22
    ano_proj = 2017
    tipo_proj = 'PEDIF'
    
    # Variaveis de resposta
    #status = ''

#    try:
        # Requisicao para o portal de propostas da Camara
    query = {"numero": num_proj, "ano": ano_proj, "codtipo": tipo_proj}
    resposta = requests.get('https://www.camarajf.mg.gov.br/sal/listapropos.php?', params=query)

#status = resposta.status_code

    resp_format = BeautifulSoup(resposta.content, "html.parser")
    c = resp_format.find('table', {'border':'0', 'cellpadding':'0', 'cellspacing':'0', 'height':'100%', 'width':'100%'}) 
    a = c.table.tr.td.a
    #c = c.find_all('blank')
    print(c)

#    except:
#        print(resposta.status_code)
# Out:
# <table border="0" cellpadding="0" cellspacing="0" height="100%" width="100%">
# <tr>
# <td align="center" valign="top">
# <table border="0" cellpadding="1" cellspacing="0" width="770">
# <tr>
# <td bgcolor="A2A88A" valign="top">
# <table bgcolor="#FFFFFF" border="0" cellpadding="0" cellspacing="0" width="1000">
# <tr>
# <td valign="top" width="1000">
# <div align="center"><img src="img/cabecalho_novo.png"/> </div></td>
# </tr>
# <tr bgcolor="FFFFFF"><td height="5"></td></tr>
# <tr><td valign="top">
# <table bgcolor="F1F2EE" width="100%">
# <tr valign="top">
# <td bgcolor="FFFFFF">
# <table border="0" width="100%">
# <tr>
# <td width="2%"> </td>
# <td width="97%"><center><b>Lista Proposições<b><center></center></b></b></center></td>
# <td width="1%"> </td>
# </tr>
# <tr>
# <td width="2%"> </td>
# <td><br/>
# <div style="float: right;"><button class="ui-button ui-widget ui-corner-all" onclick="javascript:exportar_excel()" type="button"><i aria-hidden="true" class="fa fa-file-excel-o"></i> Exportar Excel</button></div><!-- Fim do menu superior -->
# <!-- Inicio da area de operacoes: -->
# <center>
# <table align="center" border="0" cellpadding="0" cellspacing="0" width="970">
# <tr>
# <td align="left" width="52"><a href="buscapropos.php">Filtrar</a></td>
# <td colspan="9">   Foram encontradas 2 ocorrências</td>
# <td width="71"></td>
# </tr>
# <tr><td colspan="11"> </td></tr>
# <tr>
# <td align="left">Projeto</td>
# <td align="left" width="8"> </td>
# <td align="left" width="37">Ano</td>
# <td align="left" width="7"> </td>
# <td align="left" width="122">Tipo</td>
# <td align="left" width="7"> </td>
# <td align="center" width="113"><div align="left">Autor</div></td>
# <td align="left" width="4"> </td>
# <td align="right" width="538"><div align="left">Ementa</div></td>
# <td align="left" width="11"> </td>
# <td align="left" width="71"><div align="left">Situação</div></td>
# </tr>
# <tr bgcolor="F1F2EE">
# <td align="left">
# <a href="proposicao.php?num=61638" target="blank">022</a>
# </td>
# <td align="left">
#
# 				</td>
# <td align="left">
# <a href="proposicao.php?num=61638" target="blank">2017</a>
# </td>
# <td align="left">
#
# 				</td>
# <td align="left">
# <a href="proposicao.php?num=61638" target="blank">Pedido de Informação FiscalizaJF</a>
# </td>
# <td align="left">
# 				<td>
# <a href="proposicao.php?num=61638" target="blank">Mesa Diretora - biênio 2017/2018</a>
# </td>
# <td align="left">
# 				</td><td>
# <a href="proposicao.php?num=61638" target="blank"><span style="text-align: justify; display:block;">Solicita informações sobre a Escola Municipal Jardim de Alá.</span></a>
# </td><td align="left">
#
# 				</td>
# <td>
# <a href="proposicao.php?num=61638" target="blank">Arquivada</a>
# </td>
# </td></tr>
# <tr>
# <td colspan="7"> </td>
# </tr>
# <tr bgcolor="FFFFFF">
# <td align="left">
# <a href="proposicao.php?num=60020" target="blank">022</a>
# </td>
# <td align="left">
#
# 				</td>
# <td align="left">
# <a href="proposicao.php?num=60020" target="blank">2017</a>
# </td>
# <td align="left">
#
# 				</td>
# <td align="left">
# <a href="proposicao.php?num=60020" target="blank">Pedido de Informação</a>
# </td>
# <td align="left">
# 				<td>
# <a href="proposicao.php?num=60020" target="blank">Sargento Mello Casal</a>
# </td>
# <td align="left">
# 				</td><td>
# <a href="proposicao.php?num=60020" target="blank"><span style="text-align: justify; display:block;">Solicita informações sobre os profissionais não docentes das instituições de Educação Infantil, públicas e privadas.</span></a>
# </td><td align="left">
#
# 				</td>
# <td>
# <a href="proposicao.php?num=60020" target="blank">Arquivada</a>
# </td>
# </td></tr>
# <tr>
# <td colspan="7"> </td>
# </tr>
# <tr>
# <td colspan="11"><center><br/></center></td>
# </tr>
# </table>
# </center>
# <!-- Fim da area de operacoes: --> </td>
# <td width="1%"> </td>
# </tr>
# <tr>
# <td> </td>
# <td>
# <div id="carregando" style="visibility: hidden;">
# <table border="0" cellspacing="1" width="100%">
# <tr>
# <td width="100%">
# <p align="center">
# <img border="0" height="19" src="../imagens/loading.gif" width="220"/></p></td>
# </tr>
# </table>
# </div> </td>
# <tr>
# <td> </td>
# <td>
# <table border="0" cellspacing="1" width="100%">
# <tr>
# <td width="100%">
# <p align="center">
# <input onclick="location.href='buscapropos.php'" style="border:0;padding:5px 15px;font-weight: bold; font-size: 12px; color: #fff; background-color: #6b6b6b;margin:5px 0 10px;" type="button" value="Retornar"/>
# </p>
# </td>
# </tr>
# </table>
# </td>
# </tr>
# </tr></table> </td>
# </tr>
# </table>
# </td>
# </tr>
# </table>
# <script>
#   function exportar_excel() {
#       location.href = location.href + "&out=csv";
#    }
# </script>
# </td></tr></table></td></tr></table>
